# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
#stateful
x = np.linspace(-2,3,20)
y = x**3
plt.plot(x,y)
#plt.show()

# %%
#stateless
fig = plt.figure(figsize = (3,2))
#ax = plt.subplot()
ax = fig.add_subplot() #can be useful when we are dealing with multiple figurs
ax.plot(x,y)

# %%
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

fig,ax = plt.subplots(figsize = (5,3)) #one liner
ax.plot(years, chemical_exports)
plt.show()

# %%
#plt.title('LCI exports in 12 years')
#plt.show()
# the above code is not possible because it creates a new figure rather calling
#the previous cell. We have to paste the code as well

# %%
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports)
plt.title('LCI exports in 12 years')
plt.show()

# %%
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports)
plt.title('LCI exports in 12 years')
ax.set_xlabel('Years')
ax.set_ylabel('Amount (Million US$)')

plt.show()

# %%
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports)

plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')


xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)
plt.show()

# %%
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


fig,ax = plt.subplots(figsize = (5,3)) #one liner
ax.plot(years, chemical_exports)
ax.plot(years, medicine_exports)


plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')


xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)


plt.show()

# %%
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals')
# ax.plot(years, medicine_exports, label = 'Medicines')
fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, label = 'Chemicals')
ax.plot(years, medicine_exports, label = 'Medicines')

plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')


xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.show()

# %%
#can we use fig. instead of plt.
#not with every, with tight layout or may be if we define fig and ax in different lines
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals')
# ax.plot(years, medicine_exports, label = 'Medicines')

fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, label = 'Chemicals')
ax.plot(years, medicine_exports, label = 'Medicines')
plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')

fig.tight_layout()
xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.show()

# %%
#can we use fig. instead of plt.
#not with every, with tight layout or may be if we define fig and ax in different lines
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o')
# ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x')

fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, label = 'Chemicals', marker= 'o')
ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x')
plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')

fig.tight_layout()
xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.show()

# %%
#can we use fig. instead of plt.
#not with every, with tight layout or may be if we define fig and ax in different lines
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
# ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':', lw = 2)
fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, label = 'Chemicals',marker = 'o', c = 'k', ls = '-', lw = 2)
ax.plot(years, medicine_exports, label = 'Medicines',marker = 'x', c = 'm', ls = ':', lw = 2)

plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')

fig.tight_layout()
xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.show()

# %%
#can we use fig. instead of plt.
#not with every, with tight layout or may be if we define fig and ax in different lines
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
# ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':', lw = 2)

fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':' , lw = 2)
plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')

fig.tight_layout()
xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.show()

# %%
#can we use fig. instead of plt.
#not with every, with tight layout or may be if we define fig and ax in different lines
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
# ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':', lw = 2)

fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, 'o-k', label = 'Chemicals', lw = 2)
ax.plot(years, medicine_exports, 'x-m',label = 'Medicines' , lw = 2)
plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')

fig.tight_layout()
xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.show()

# %%
#can we use fig. instead of plt.
#not with every, with tight layout or may be if we define fig and ax in different lines
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
# ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':', lw = 2)

fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':' , lw = 2)
plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')

fig.tight_layout()
xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.grid(True)
plt.show()

# %%
#can we use fig. instead of plt.
#not with every, with tight layout or may be if we define fig and ax in different lines
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
# ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':', lw = 2)

fig = plt.figure(figsize = (5,3))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':' , lw = 2)
plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')

fig.tight_layout()
xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.grid(True)

plt.annotate("Peak of chemical exports", xy = (2016,0.95))
plt.annotate("Peak of medicine exports", xy = (2021,0.94))

plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#can we use fig. instead of plt.
#not with every, with tight layout or may be if we define fig and ax in different lines
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931,
                    0.919, 0.921, 0.920, 0.919]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# fig,ax = plt.subplots(figsize = (5,3)) #one liner
# ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
# ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':', lw = 2)

fig = plt.figure(figsize = (8,6))
#ax = plt.subplot()
ax = fig.add_subplot()
ax.plot(years, chemical_exports, label = 'Chemicals', marker = 'o', c = 'k', ls = '-', lw = 2)
ax.plot(years, medicine_exports, label = 'Medicines', marker = 'x', c = 'm', ls = ':' , lw = 2)
plt.title('LCI exports in 12 years')


ax.set_xlabel('Years')


ax.set_ylabel('Amount (Million US$)')

fig.tight_layout()
xvals = np.arange(2010, 2022, 2)
yvals = np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yvals)

plt.legend(loc = 'best')

plt.grid(True)

plt.annotate("Peak of chemical exports", xy = (2016,0.95))
plt.annotate("Peak of medicine exports", xy = (2021,0.94))


plt.style.use('default')
#plt.style.use('dark_background')
#plt.style.use('fivethirtyeight')
#plt.style.use('ggplot')

plt.savefig('LCI.png')  # can use .pdf, .ps, .eps, .svg formats
plt.show()

# %%
fig, ax = plt.subplots(nrows=3, ncols=3)
print(ax)
# Out:
# [[<AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]]

# %%
#multiple axes single figure
from matplotlib import pyplot as plt
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)

ax1.plot(years, chemical_exports, label='Chemicals', marker='o', c='b', ls='-', lw=2) 
ax1.set_title("LCI Chemical exports in last 12 years")
ax1.set_xlabel("Years")
ax1.set_ylabel("Amount (Million Rs.)")

ax2.plot(years, medicine_exports, label='Medicines', marker='x', c='r', ls=':', lw=2) 
ax2.set_title("LCI Medicine exports in last 12 years")
ax2.set_xlabel("Years")
ax2.set_ylabel("Amount (Million Rs.)")

plt.tight_layout()
plt.show()

# %%
#multiple figures multiple axes
from matplotlib import pyplot as plt
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]


fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

ax1.plot(years, chemical_exports, label='Chemicals', marker='o', c='b', ls='-', lw=2) 
ax1.set_title("LCI Chemical exports in last 12 years")
ax1.set_xlabel("Years")
ax1.set_ylabel("Amount (Million Rs.)")

ax2.plot(years, medicine_exports, label='Medicines', marker='x', c='r', ls=':', lw=2) 
ax2.set_title("LCI Medicine exports in last 12 years")
ax2.set_xlabel("Years")
ax2.set_ylabel("Amount (Million Rs.)")

plt.tight_layout()
plt.show()
